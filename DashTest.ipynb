# %%
from IPython.display import IFrame
IFrame(
    src="https://dash-simple-apps.plotly.host/dash-linescatterplot/",
    width="50%",
    height="375px",
    frameBorder="0"
)
# Out:
#         <iframe
#             width="50%"
#             height="375px"
#             src="https://dash-simple-apps.plotly.host/dash-linescatterplot/?frameBorder=0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
